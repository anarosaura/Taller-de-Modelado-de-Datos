# %% [markdown]
# ___
# <img style="float: right; margin: 0px 0px 15px 15px;" src="http://www.lintao-dashboards.com/wp-content/uploads/2016/02/ldm930.jpg" width="350px" height="180px" />
#
# # <font color= #8A0829> Proyecto Taller de Modelado de Datos </font>
# - <Strong> `ANA ROSAURA ZAMARRÓN ÁLVAREZ` </Strong>
# - <Strong> Año </Strong>: 2021
# - <Strong> Email: </Strong>  <font color="blue"> `ana.zamarron@iteso.mx` </font>
# ___
#
# <p style="text-align:right;"> Imagen recuperada de: http://www.lintao-dashboards.com/wp-content/uploads/2016/02/ldm930.jpg.</p>

# %% [markdown]
# # Regresión -  Student Performance (math)

# %% [markdown]
# Para este proyecto queremos predecir las calificaciones de los estudiantes de la materia de matemáticas dependiendo de diferentes variables sobre sus estudios y su vida personal.

# %% [markdown]
# #### Attribute Information:
#
# Attributes for both student-mat.csv (Math course) and student-por.csv (Portuguese language course) datasets:
# 1. school - student's school (binary: 'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)
# 2. sex - student's sex (binary: 'F' - female or 'M' - male)
# 3. age - student's age (numeric: from 15 to 22)
# 4. address - student's home address type (binary: 'U' - urban or 'R' - rural)
# 5. famsize - family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)
# 6. Pstatus - parent's cohabitation status (binary: 'T' - living together or 'A' - apart)
# 7. Medu - mother's education (numeric: 0 - none, 1 - primary education (4th grade), 2 â€“ 5th to 9th grade, 3 â€“ secondary education or 4 â€“ higher education)
# 8. Fedu - father's education (numeric: 0 - none, 1 - primary education (4th grade), 2 â€“ 5th to 9th grade, 3 â€“ secondary education or 4 â€“ higher education)
# 9. Mjob - mother's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# 10. Fjob - father's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# 11. reason - reason to choose this school (nominal: close to 'home', school 'reputation', 'course' preference or 'other')
# 12. guardian - student's guardian (nominal: 'mother', 'father' or 'other')
# 13. traveltime - home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)
# 14. studytime - weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
# 15. failures - number of past class failures (numeric: n if 1<=n<3, else 4)
# 16. schoolsup - extra educational support (binary: yes or no)
# 17. famsup - family educational support (binary: yes or no)
# 18. paid - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
# 19. activities - extra-curricular activities (binary: yes or no)
# 20. nursery - attended nursery school (binary: yes or no)
# 21. higher - wants to take higher education (binary: yes or no)
# 22. internet - Internet access at home (binary: yes or no)
# 23. romantic - with a romantic relationship (binary: yes or no)
# 24. famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
# 25. freetime - free time after school (numeric: from 1 - very low to 5 - very high)
# 26. goout - going out with friends (numeric: from 1 - very low to 5 - very high)
# 27. Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
# 28. Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
# 29. health - current health status (numeric: from 1 - very bad to 5 - very good)
# 30. absences - number of school absences (numeric: from 0 to 93)
#
# These grades are related with the course subject, Math:
#
# 31. G1 - first period grade (numeric: from 0 to 20)
# 31. G2 - second period grade (numeric: from 0 to 20)
# 32. G3 - final grade (numeric: from 0 to 20, output target)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('student-mat.csv', sep = ';')

# %%
data
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
data.shape
# Out:
# (395, 33)

# %% [markdown]
# Tenemos 395 instancias y 33 variables.

# %%
data['G3'].min(), data['G3'].max()
# Out:
# (0, 20)

# %% [markdown]
# Las calficaciones van de 0 a 20.

# %% [markdown]
# #### Exploración de datos

# %% [markdown]
# Con las variables de $x$ podemos predecir las calificaciones del primer periodo `G1`, las del segundo periodo `G2` y la calificación final `G3`. Solo vamos a predecir la calificación final.

# %%
data['G3'].value_counts()
# Out:
# 10    56
# 11    47
# 0     38
# 15    33
# 8     32
# 13    31
# 12    31
# 9     28
# 14    27
# 16    16
# 6     15
# 18    12
# 7      9
# 5      7
# 17     6
# 19     5
# 4      1
# 20     1
# Name: G3, dtype: int64

# %%
sns.countplot(x='G3', data=data)
plt.title('Calificaciones finales')
plt.show()

# %% [markdown]
# La calificación más frecuente es 10, los datos se ven imbalanceados, hay mucha diferencia entre la frecuencia de una calificación de 4 y una de 10.

# %%
data.hist(color='purple', alpha=0.5, bins=10,figsize =(20,20))
plt.show()

# %% [markdown]
# Casi todas las variables son discretas. A continuación, analizaremos el sesgo de cada variable.

# %%
numerical_df = data.select_dtypes(exclude = 'object')
numerical_df.head(3)
# Out:
#    age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  goout  \
# 0   18     4     4           2          2         0       4         3      4
# 1   17     1     1           1          2         0       5         3      3
# 2   15     1     1           1          2         3       4         3      2
#
#    Dalc  Walc  health  absences  G1  G2  G3
# 0     1     1       3         6   5   6   6
# 1     1     1       3         4   5   5   6
# 2     2     3       3        10   7   8  10

# %%
for i in numerical_df.columns:
    skew = data[i].skew()
    if skew > 0:
        print(f'Sesgo de {i}:',skew,' Esta variable tiene sesgo positivo.')
    
    else:
        print(f'Sesgo de {i}:',skew,' Esta variable tiene sesgo negativo.')
# Out:
# Sesgo de age: 0.46627016141836425  Esta variable tiene sesgo positivo.
# Sesgo de Medu: -0.31838068845785517  Esta variable tiene sesgo negativo.
# Sesgo de Fedu: -0.03167209443510635  Esta variable tiene sesgo negativo.
# Sesgo de traveltime: 1.6070291037557645  Esta variable tiene sesgo positivo.
# Sesgo de studytime: 0.6321422002561792  Esta variable tiene sesgo positivo.
# Sesgo de failures: 2.38702572387036  Esta variable tiene sesgo positivo.
# Sesgo de famrel: -0.951881690060932  Esta variable tiene sesgo negativo.
# Sesgo de freetime: -0.16335075302040777  Esta variable tiene sesgo negativo.
# Sesgo de goout: 0.11650241685363202  Esta variable tiene sesgo positivo.
# Sesgo de Dalc: 2.190761845462348  Esta variable tiene sesgo positivo.
# Sesgo de Walc: 0.6119599829215362  Esta variable tiene sesgo positivo.
# Sesgo de health: -0.49460356816790363  Esta variable tiene sesgo negativo.
# Sesgo de absences: 3.6715789504758862  Esta variable tiene sesgo positivo.
# ...

# %%
data.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %% [markdown]
# No tenemos variables con datos nulos.

# %%
data.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %% [markdown]
# Tenemos 16 variables numéricas y 17 categóricas.

# %%
data.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
corr = data[['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
       'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
       'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
       'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
       'Walc', 'health', 'absences', 'G1', 'G2', 'G3']].select_dtypes(exclude=['object']).corr()

fig, ax = plt.subplots(figsize=(8, 8))
ax.matshow(corr, cmap='Greens')

ax.set_xticks(range(len(corr.columns)))
ax.set_xticklabels(corr.columns, rotation=90)

ax.set_yticks(range(len(corr.columns)))
ax.set_yticklabels(corr.columns)

#plt.suptitle('Correlation heatmap\n\n', fontsize=10)

ax.grid(False)

# %% [markdown]
# Podemos observar que las variables con mayor correlación con la variable de respuesta `G3` son `G1`,`G2`,`failures`, `traveltime`, `Medu`. Yo creo que como `G1` y `G2` son parecidas a la variable de respuesta entonces tienen mayor correlación, yo creo que esto puede generar leakage, por eso conviene quitarlas del data set.

# %%
data.drop(['G1','G2'], axis = 1, inplace = True)

# %%
data.head(3)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home  teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home    other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home    other  ...
#
#   internet romantic  famrel  freetime  goout Dalc Walc health absences  G3
# 0       no       no       4         3      4    1    1      3        6   6
# 1      yes       no       5         3      3    1    1      3        4   6
# 2      yes       no       4         3      2    2    3      3       10  10
#
# [3 rows x 31 columns]

# %%
numerical_df.drop(['G1','G2'], axis = 1, inplace = True)
# Out:
# /Users/rosaura/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
numerical_df.head(3)
# Out:
#    age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  goout  \
# 0   18     4     4           2          2         0       4         3      4
# 1   17     1     1           1          2         0       5         3      3
# 2   15     1     1           1          2         3       4         3      2
#
#    Dalc  Walc  health  absences  G3
# 0     1     1       3         6   6
# 1     1     1       3         4   6
# 2     2     3       3        10  10

# %%
min(data['age'].unique()), max(data['age'].unique())
# Out:
# (15, 22)

# %% [markdown]
# Las edades de los estudiantes van de 15 a 22 años.

# %%
categorical_df = data.select_dtypes(include = 'object')
categorical_df.head()
# Out:
#   school sex address famsize Pstatus     Mjob      Fjob  reason guardian  \
# 0     GP   F       U     GT3       A  at_home   teacher  course   mother
# 1     GP   F       U     GT3       T  at_home     other  course   father
# 2     GP   F       U     LE3       T  at_home     other   other   mother
# 3     GP   F       U     GT3       T   health  services    home   mother
# 4     GP   F       U     GT3       T    other     other    home   father
#
#   schoolsup famsup paid activities nursery higher internet romantic
# 0       yes     no   no         no     yes    yes       no       no
# 1        no    yes   no         no      no    yes      yes       no
# 2       yes     no  yes         no     yes    yes      yes       no
# 3        no    yes  yes        yes     yes    yes      yes      yes
# 4        no    yes  yes         no     yes    yes       no       no

# %%
plt.figure(figsize = (15,5))
for col in categorical_df.columns:
    long = len(data[col].unique())
    plt.bar(col,long)

plt.title('Granularidad')
plt.xlabel('Column')
plt.ylabel('Number of unique values')
plt.show()

# %%
def create_bins(df, variable, n):
    """
    Función auxiliar para generar bins (percentiles)
    """
    try:
        bins = pd.qcut(df[variable], n, duplicates='drop')
        df[f'bins_{variable}'] = bins
    except:
        df[f'bins_{variable}'] = df[variable].values
    return df

# %%
plt.figure(figsize=(10, 30))

# Generemos una copia
copy = data.copy()

# Recorramos las variables en un for
for i in data:
    
    # Seleccionamos las columnas
    cols = i

    # Crear los bins
    copy = create_bins(copy, cols, 5)

    # Agrupación
    copy.groupby(f'bins_{cols}').agg({'G3': 'mean'}).plot(rot=90)

    # Título
    plt.title(f'Var: {cols}')
    
fig.tight_layout()
# Out:
# /Users/rosaura/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)

# %% [markdown]
# Parece que todas las variables son buenas menos `Mjob`,`Fjob`, `freetime`, `health`, y `absences`.

# %% [markdown]
# #### Datos atípicos

# %%
data.boxplot(figsize=(10,8), rot=90)
plt.title('Datos atípicos')
# Out:
# Text(0.5, 1.0, 'Datos atípicos')

# %% [markdown]
# Podemos ver que `absences` tiene datos atípicos muy alejados. `age`, `traveltime`, `failures`, `famrel`, `freetime`, `Dalc`. también tienen datos atípicos pero no están tan alejados.

# %%
data.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
#Analizar variable Y vs Sexo
table = pd.crosstab(data.G3,data.sex)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Sexo vs G3')
plt.xlabel('G3')
plt.ylabel('sexo')
# Out:
# Text(0, 0.5, 'sexo')

# %% [markdown]
# Está balanceado, no nos sirve mucho para predecir.

# %%
#Analizar variable Y vs romantic
table = pd.crosstab(data.G3,data.romantic)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('romantic vs G3')
plt.xlabel('G3')
plt.ylabel('romantic')
# Out:
# Text(0, 0.5, 'romantic')

# %% [markdown]
# Podemos ver que de los estudiantes que sacaron 19 y 20 de calificación, que son las calificaciones más altas, ninguno tiene pareja. Y del resto, la mayoría no tiene pareja. No está balanceada, puede ser una buena variable predictora.

# %%
#Analizar variable Y vs internet
table = pd.crosstab(data.G3,data.internet)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('internet vs G3')
plt.xlabel('G3')
plt.ylabel('internet')
# Out:
# Text(0, 0.5, 'internet')

# %% [markdown]
# La mayoría sí tiene internet, no nos sirve tanto para predecir. Pero qué impresionante que a pesar de que algunos estudiantes no tienen internet en casa lograron sacar 15, 17 o 18 de calificación.

# %%
#Analizar variable Y vs Higher education
table = pd.crosstab(data.G3,data.higher)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Higher education vs G3')
plt.xlabel('G3')
plt.ylabel('higher education')
# Out:
# Text(0, 0.5, 'higher education')

# %% [markdown]
# La mayoría sí quiere seguir estudiando, no es una variable que nos pueda servir mucho para predecir porque muy poquitos dijeron que no.

# %%
#Analizar variable Y vs Nursery
table = pd.crosstab(data.G3,data.nursery)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Nursery vs G3')
plt.xlabel('G3')
plt.ylabel('nursery')
# Out:
# Text(0, 0.5, 'nursery')

# %% [markdown]
# La mayoría sí atendió a la escuela de enfermería, pero los datos no están balanceados. Sí nos sirve para predecir.

# %%
#Analizar variable Y vs activities
table = pd.crosstab(data.G3,data.activities)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('activities vs G3')
plt.xlabel('G3')
plt.ylabel('activities')
# Out:
# Text(0, 0.5, 'activities')

# %% [markdown]
# La proporción se ve más o menos imbalanceada, sí nos puede servir para predecir.

# %%
#Analizar variable Y vs paid
table = pd.crosstab(data.G3,data.paid)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('paid vs G3')
plt.xlabel('G3')
plt.ylabel('paid')
# Out:
# Text(0, 0.5, 'paid')

# %% [markdown]
# Tampoco se ve balanceada, nos sirve para predecir.

# %%
#Analizar variable Y vs. famsup
table = pd.crosstab(data.G3,data.famsup)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('famsup vs G3')
plt.xlabel('G3')
plt.ylabel('famsup')
# Out:
# Text(0, 0.5, 'famsup')

# %% [markdown]
# Tampoco se ve balanceada, nos sirve para predecir.

# %%
#Analizar variable Y vs. guardian
table = pd.crosstab(data.G3,data.guardian)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('guardian vs G3')
plt.xlabel('G3')
plt.ylabel('guardian')
# Out:
# Text(0, 0.5, 'guardian')

# %% [markdown]
# No se ve balanceada, nos sirve para predecir.

# %%
#Analizar variable Y vs. reason
table = pd.crosstab(data.G3,data.reason)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('reason vs G3')
plt.xlabel('G3')
plt.ylabel('reason')
# Out:
# Text(0, 0.5, 'reason')

# %% [markdown]
# No se ve balanceada, nos sirve para predecir.

# %%
#Analizar variable Y vs. Fjob
table = pd.crosstab(data.G3,data.Fjob)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Fjob vs G3')
plt.xlabel('G3')
plt.ylabel('Fjob')
# Out:
# Text(0, 0.5, 'Fjob')

# %% [markdown]
# No se ve balanceada, nos sirve para predecir.

# %%
#Analizar variable Y vs. Mjob
table = pd.crosstab(data.G3,data.Mjob)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Mjob vs G3')
plt.xlabel('G3')
plt.ylabel('Mjob')
# Out:
# Text(0, 0.5, 'Mjob')

# %% [markdown]
# No se ve balanceada, nos sirve para predecir.

# %%
#Analizar variable Y vs. Pstatus
table = pd.crosstab(data.G3,data.Pstatus)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Pstatus vs G3')
plt.xlabel('G3')
plt.ylabel('Pstatus')
# Out:
# Text(0, 0.5, 'Pstatus')

# %% [markdown]
# No se ve balanceada, nos sirve para predecir.

# %%
#Analizar variable Y vs. famsize
table = pd.crosstab(data.G3,data.famsize)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('famsize vs G3')
plt.xlabel('G3')
plt.ylabel('famsize')
# Out:
# Text(0, 0.5, 'famsize')

# %% [markdown]
# No se ve balanceada, nos sirve para predecir.

# %%
#Analizar variable Y vs. adress
table = pd.crosstab(data.G3,data.address)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('address vs G3')
plt.xlabel('G3')
plt.ylabel('address')
# Out:
# Text(0, 0.5, 'address')

# %% [markdown]
# No se ve balanceada, nos sirve para predecir.

# %%
#Analizar variable Y vs. school
table = pd.crosstab(data.G3,data.school)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('school vs G3')
plt.xlabel('G3')
plt.ylabel('school')
# Out:
# Text(0, 0.5, 'school')

# %% [markdown]
# No se ve balanceada, nos sirve para predecir.

# %% [markdown]
# #### Separemos los el dataset en datos de entrenamiento y de prueba.

# %%
from sklearn.model_selection import train_test_split

# %%
data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   internet romantic  famrel  freetime  goout Dalc Walc health absences  G3
# 0       no       no       4         3      4    1    1      3        6   6
# 1      yes       no       5         3      3    1    1      3        4   6
# 2      yes       no       4         3      2    2    3      3       10  10
# 3      yes      yes       3         2      2    1    1      5        2  15
# 4       no       no       4         3      2    1    2      5        4  10
#
# [5 rows x 31 columns]

# %%
categorical_df.head()
# Out:
#   school sex address famsize Pstatus     Mjob      Fjob  reason guardian  \
# 0     GP   F       U     GT3       A  at_home   teacher  course   mother
# 1     GP   F       U     GT3       T  at_home     other  course   father
# 2     GP   F       U     LE3       T  at_home     other   other   mother
# 3     GP   F       U     GT3       T   health  services    home   mother
# 4     GP   F       U     GT3       T    other     other    home   father
#
#   schoolsup famsup paid activities nursery higher internet romantic
# 0       yes     no   no         no     yes    yes       no       no
# 1        no    yes   no         no      no    yes      yes       no
# 2       yes     no  yes         no     yes    yes      yes       no
# 3        no    yes  yes        yes     yes    yes      yes      yes
# 4        no    yes  yes         no     yes    yes       no       no

# %% [markdown]
# Utilizamos One-Hot para convertir variables categóricas a numéricas.

# %%
dummies = pd.get_dummies(categorical_df)
dummies
# Out:
#      school_GP  school_MS  sex_F  sex_M  address_R  address_U  famsize_GT3  \
# 0            1          0      1      0          0          1            1
# 1            1          0      1      0          0          1            1
# 2            1          0      1      0          0          1            0
# 3            1          0      1      0          0          1            1
# 4            1          0      1      0          0          1            1
# ..         ...        ...    ...    ...        ...        ...          ...
# 390          0          1      0      1          0          1            0
# 391          0          1      0      1          0          1            0
# 392          0          1      0      1          1          0            1
# 393          0          1      0      1          1          0            0
# 394          0          1      0      1          0          1            0
#
# ...

# %%
df = data.copy()
df.head(2)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home  teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home    other  ...
#
#   internet romantic  famrel  freetime  goout Dalc Walc health absences G3
# 0       no       no       4         3      4    1    1      3        6  6
# 1      yes       no       5         3      3    1    1      3        4  6
#
# [2 rows x 31 columns]

# %%
categorical_df.columns
# Out:
# Index(['school', 'sex', 'address', 'famsize', 'Pstatus', 'Mjob', 'Fjob',
#        'reason', 'guardian', 'schoolsup', 'famsup', 'paid', 'activities',
#        'nursery', 'higher', 'internet', 'romantic'],
#       dtype='object')

# %%
df.drop(columns = ['school', 'sex', 'address', 'famsize', 'Pstatus', 'Mjob', 'Fjob',
       'reason', 'guardian', 'schoolsup', 'famsup', 'paid', 'activities',
       'nursery', 'higher', 'internet', 'romantic'], inplace = True)
df.head()
# Out:
#    age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  goout  \
# 0   18     4     4           2          2         0       4         3      4
# 1   17     1     1           1          2         0       5         3      3
# 2   15     1     1           1          2         3       4         3      2
# 3   15     4     2           1          3         0       3         2      2
# 4   16     3     3           1          2         0       4         3      2
#
#    Dalc  Walc  health  absences  G3
# 0     1     1       3         6   6
# 1     1     1       3         4   6
# 2     2     3       3        10  10
# 3     1     1       5         2  15
# 4     1     2       5         4  10

# %% [markdown]
# Unimos las variables numéricas con los dummies.

# %%
df = df.join(dummies)

# %%
df
# Out:
#      age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  \
# 0     18     4     4           2          2         0       4         3
# 1     17     1     1           1          2         0       5         3
# 2     15     1     1           1          2         3       4         3
# 3     15     4     2           1          3         0       3         2
# 4     16     3     3           1          2         0       4         3
# ..   ...   ...   ...         ...        ...       ...     ...       ...
# 390   20     2     2           1          2         2       5         5
# 391   17     3     1           2          1         0       2         4
# 392   21     1     1           1          1         3       5         5
# 393   18     3     2           3          1         0       4         4
# 394   19     1     1           1          1         0       3         2
#
#      goout  Dalc  ...  activities_no  activities_yes  nursery_no  nursery_yes  \
# ...

# %%
df.drop('G3',axis = 1,inplace = True)

# %%
df['y'] = data['G3']

# %%
df
# Out:
#      age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  \
# 0     18     4     4           2          2         0       4         3
# 1     17     1     1           1          2         0       5         3
# 2     15     1     1           1          2         3       4         3
# 3     15     4     2           1          3         0       3         2
# 4     16     3     3           1          2         0       4         3
# ..   ...   ...   ...         ...        ...       ...     ...       ...
# 390   20     2     2           1          2         2       5         5
# 391   17     3     1           2          1         0       2         4
# 392   21     1     1           1          1         3       5         5
# 393   18     3     2           3          1         0       4         4
# 394   19     1     1           1          1         0       3         2
#
#      goout  Dalc  ...  activities_yes  nursery_no  nursery_yes  higher_no  \
# ...

# %% [markdown]
# + Ahora tenemos nuestro dataframe con las variables numéricas y las variables encodeadas con One-Hot.
# + Tenemos un dataframe de 57 columnas

# %%
df.dtypes
# Out:
# age                  int64
# Medu                 int64
# Fedu                 int64
# traveltime           int64
# studytime            int64
# failures             int64
# famrel               int64
# freetime             int64
# goout                int64
# Dalc                 int64
# Walc                 int64
# health               int64
# absences             int64
# school_GP            uint8
# school_MS            uint8
# sex_F                uint8
# sex_M                uint8
# address_R            uint8
# address_U            uint8
# famsize_GT3          uint8
# famsize_LE3          uint8
# Pstatus_A            uint8
# Pstatus_T            uint8
# Mjob_at_home         uint8
# Mjob_health          uint8
# Mjob_other           uint8
# Mjob_services        uint8
# Mjob_teacher         uint8
# Fjob_at_home         uint8
# Fjob_health          uint8
# Fjob_other           uint8
# Fjob_services        uint8
# Fjob_teacher         uint8
# reason_course        uint8
# ...

# %% [markdown]
# Ya no tenemos varibales de tipo object.

# %%
df.iloc[:,0:56].head()
# Out:
#    age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  goout  \
# 0   18     4     4           2          2         0       4         3      4
# 1   17     1     1           1          2         0       5         3      3
# 2   15     1     1           1          2         3       4         3      2
# 3   15     4     2           1          3         0       3         2      2
# 4   16     3     3           1          2         0       4         3      2
#
#    Dalc  ...  activities_no  activities_yes  nursery_no  nursery_yes  \
# 0     1  ...              1               0           0            1
# 1     1  ...              1               0           1            0
# 2     2  ...              1               0           0            1
# 3     1  ...              0               1           0            1
# 4     1  ...              1               0           0            1
#
#    higher_no  higher_yes  internet_no  internet_yes  romantic_no  romantic_yes
# ...

# %% [markdown]
# #### train/test

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop(columns = ['y']), df['y'], 
                                                    test_size = 0.2, random_state=42)

# %%
X_train
# Out:
#      age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  \
# 181   16     3     3           1          2         0       4         2
# 194   16     2     3           2          1         0       5         3
# 173   16     1     3           1          2         3       4         3
# 63    16     4     3           1          3         0       3         4
# 253   16     2     1           2          1         0       3         3
# ..   ...   ...   ...         ...        ...       ...     ...       ...
# 71    15     4     2           1          4         0       3         3
# 106   15     2     2           1          4         0       5         1
# 270   19     3     3           1          2         2       4         3
# 348   17     4     3           1          3         0       4         4
# 102   15     4     4           1          1         0       5         3
#
#      goout  Dalc  ...  activities_no  activities_yes  nursery_no  nursery_yes  \
# ...

# %% [markdown]
# #### Normalización

# %% [markdown]
# Normalizamos solamente las variables predictoras.

# %%
#Escalar datos
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_test
# Out:
# array([[ 0.20211949, -0.68063585, -1.43420275, ...,  0.43869446,
#          0.72565146, -0.72565146],
#        [ 0.99063503, -1.60770883, -0.50549769, ...,  0.43869446,
#         -1.37807205,  1.37807205],
#        [ 0.99063503,  0.24643712,  0.42320737, ...,  0.43869446,
#         -1.37807205,  1.37807205],
#        ...,
#        [-1.37491159, -0.68063585, -1.43420275, ...,  0.43869446,
#         -1.37807205,  1.37807205],
#        [-1.37491159,  1.17351009, -0.50549769, ...,  0.43869446,
#         -1.37807205,  1.37807205],
#        [ 0.20211949,  0.24643712, -0.50549769, ...,  0.43869446,
#          0.72565146, -0.72565146]])

# %% [markdown]
# #### Selección de variables

# %% [markdown]
# Compararemos la selección de variables de los modelos LASSO y el modelo basado en árboles.

# %%
X_train
# Out:
# array([[-0.58639605,  0.24643712,  0.42320737, ...,  0.43869446,
#         -1.37807205,  1.37807205],
#        [-0.58639605, -0.68063585,  0.42320737, ...,  0.43869446,
#          0.72565146, -0.72565146],
#        [-0.58639605, -1.60770883,  0.42320737, ...,  0.43869446,
#         -1.37807205,  1.37807205],
#        ...,
#        [ 1.77915057,  0.24643712,  0.42320737, ...,  0.43869446,
#          0.72565146, -0.72565146],
#        [ 0.20211949,  1.17351009,  0.42320737, ...,  0.43869446,
#         -1.37807205,  1.37807205],
#        [-1.37491159,  1.17351009,  1.35191243, ...,  0.43869446,
#          0.72565146, -0.72565146]])

# %%
X_train.shape
# Out:
# (316, 56)

# %%
y_train
# Out:
# 181    12
# 194    14
# 173     0
# 63      9
# 253     8
#        ..
# 71     10
# 106     8
# 270     9
# 348    15
# 102    14
# Name: y, Length: 316, dtype: int64

# %% [markdown]
# #### Lasso

# %%
##LASSO
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel

sel=LogisticRegression(C=1, penalty='l1', solver='liblinear').fit(X_train, y_train)
#sel=LogisticRegression(C=1, penalty='l1', solver='liblinear').fit(X,Y)
sel=SelectFromModel(sel, prefit=True)
X_new=sel.transform(X_train)
#X_new=sel.transform(X)
X_new.shape
# Out:
# (316, 56)

# %% [markdown]
# Data frame sin las variables que Lasso eliminó:

# %%
pd.DataFrame(X_new)
# Out:
#            0         1         2         3         4         5         6   \
# 0   -0.586396  0.246437  0.423207 -0.625779 -0.056853 -0.456744  0.064432
# 1   -0.586396 -0.680636  0.423207  0.828236 -1.254553 -0.456744  1.195575
# 2   -0.586396 -1.607709  0.423207 -0.625779 -0.056853  3.628097  0.064432
# 3   -0.586396  1.173510  0.423207 -0.625779  1.140847 -0.456744 -1.066710
# 4   -0.586396 -0.680636 -1.434203  0.828236 -1.254553 -0.456744 -1.066710
# ..        ...       ...       ...       ...       ...       ...       ...
# 311 -1.374912  1.173510 -0.505498 -0.625779  2.338548 -0.456744 -1.066710
# 312 -1.374912 -0.680636 -0.505498 -0.625779  2.338548 -0.456744  1.195575
# 313  1.779151  0.246437  0.423207 -0.625779 -0.056853  2.266484  0.064432
# 314  0.202119  1.173510  0.423207 -0.625779  1.140847 -0.456744  0.064432
# 315 -1.374912  1.173510  1.351912 -0.625779 -1.254553 -0.456744  1.195575
#
#            7         8         9   ...        46        47        48  \
# ...

# %%
df.columns
# Out:
# Index(['age', 'Medu', 'Fedu', 'traveltime', 'studytime', 'failures', 'famrel',
#        'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'school_GP',
#        'school_MS', 'sex_F', 'sex_M', 'address_R', 'address_U', 'famsize_GT3',
#        'famsize_LE3', 'Pstatus_A', 'Pstatus_T', 'Mjob_at_home', 'Mjob_health',
#        'Mjob_other', 'Mjob_services', 'Mjob_teacher', 'Fjob_at_home',
#        'Fjob_health', 'Fjob_other', 'Fjob_services', 'Fjob_teacher',
#        'reason_course', 'reason_home', 'reason_other', 'reason_reputation',
#        'guardian_father', 'guardian_mother', 'guardian_other', 'schoolsup_no',
#        'schoolsup_yes', 'famsup_no', 'famsup_yes', 'paid_no', 'paid_yes',
#        'activities_no', 'activities_yes', 'nursery_no', 'nursery_yes',
#        'higher_no', 'higher_yes', 'internet_no', 'internet_yes', 'romantic_no',
#        'romantic_yes', 'y'],
#       dtype='object')

# %%
X_train = pd.DataFrame(X_train, columns = ['age', 'Medu', 'Fedu', 'traveltime', 'studytime', 'failures', 'famrel',
       'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'school_GP',
       'school_MS', 'sex_F', 'sex_M', 'address_R', 'address_U', 'famsize_GT3',
       'famsize_LE3', 'Pstatus_A', 'Pstatus_T', 'Mjob_at_home', 'Mjob_health',
       'Mjob_other', 'Mjob_services', 'Mjob_teacher', 'Fjob_at_home',
       'Fjob_health', 'Fjob_other', 'Fjob_services', 'Fjob_teacher',
       'reason_course', 'reason_home', 'reason_other', 'reason_reputation',
       'guardian_father', 'guardian_mother', 'guardian_other', 'schoolsup_no',
       'schoolsup_yes', 'famsup_no', 'famsup_yes', 'paid_no', 'paid_yes',
       'activities_no', 'activities_yes', 'nursery_no', 'nursery_yes',
       'higher_no', 'higher_yes', 'internet_no', 'internet_yes', 'romantic_no',
       'romantic_yes'])
X_train
# Out:
#           age      Medu      Fedu  traveltime  studytime  failures    famrel  \
# 0   -0.586396  0.246437  0.423207   -0.625779  -0.056853 -0.456744  0.064432
# 1   -0.586396 -0.680636  0.423207    0.828236  -1.254553 -0.456744  1.195575
# 2   -0.586396 -1.607709  0.423207   -0.625779  -0.056853  3.628097  0.064432
# 3   -0.586396  1.173510  0.423207   -0.625779   1.140847 -0.456744 -1.066710
# 4   -0.586396 -0.680636 -1.434203    0.828236  -1.254553 -0.456744 -1.066710
# ..        ...       ...       ...         ...        ...       ...       ...
# 311 -1.374912  1.173510 -0.505498   -0.625779   2.338548 -0.456744 -1.066710
# 312 -1.374912 -0.680636 -0.505498   -0.625779   2.338548 -0.456744  1.195575
# 313  1.779151  0.246437  0.423207   -0.625779  -0.056853  2.266484  0.064432
# 314  0.202119  1.173510  0.423207   -0.625779   1.140847 -0.456744  0.064432
# 315 -1.374912  1.173510  1.351912   -0.625779  -1.254553 -0.456744  1.195575
#
# ...

# %% [markdown]
# + Lasso no eliminó ninguna variable. Todas las considera importantes.
# + Seguimos teniendo las 56 variables.

# %% [markdown]
# #### Árboles

# %%
### Feature Importance con clasificador de Extra Trees
from sklearn.ensemble import ExtraTreesClassifier
# crear objeto de Extra Trees
model = ExtraTreesClassifier(n_estimators=10)
#Ajustar modelo a datos
model.fit(X_train, y_train)

importances = pd.DataFrame(data={
#'Attribute': new.iloc[:,0:20].columns,
'Attribute': pd.DataFrame(X_train).columns,
'Importance': model.feature_importances_
})
importances = importances.sort_values(by='Importance', ascending=False)
# En esa tabla podemos ver desde la variable más importante hasta la menos importante
importances
# Out:
#             Attribute  Importance
# 12           absences    0.043498
# 11             health    0.038085
# 1                Medu    0.036828
# 4           studytime    0.033755
# 0                 age    0.032322
# 7            freetime    0.030882
# 10               Walc    0.030356
# 6              famrel    0.030291
# 2                Fedu    0.029772
# 8               goout    0.027812
# 5            failures    0.027190
# 19        famsize_GT3    0.024165
# 3          traveltime    0.021830
# 9                Dalc    0.021494
# 33      reason_course    0.021361
# 46      activities_no    0.020599
# 42          famsup_no    0.019914
# 43         famsup_yes    0.019806
# 53       internet_yes    0.019186
# 20        famsize_LE3    0.018973
# 26      Mjob_services    0.018927
# 34        reason_home    0.018660
# 31      Fjob_services    0.018535
# 47     activities_yes    0.018412
# 36  reason_reputation    0.018250
# 16              sex_M    0.018010
# ...

# %% [markdown]
# Como LASSO no eliminó ninguna variable, es probable que no me convenga eliminar ninguna. Pero si tuviera que elegir, eliminaría las últimas 4 que escogió el modelo basado en árboles:
# + Fjob_health
# + schoolsup_no
# + higher_no
# + higher_yes

# %% [markdown]
# A continuación, haremos el modelo de predicción.

# %% [markdown]
# Data set recuperado de: https://archive.ics.uci.edu/ml/datasets/Student+Performance

# %% [markdown]
# ## SEGUNDA PARTE DEL PROYECTO - MODELOS

# %% [markdown]
# #### Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn.metrics import mean_squared_error, r2_score, make_scorer

# %%
#Inicializamos el bosque con 300 árboles
rf_regressor = RandomForestRegressor(n_estimators = 300 ,  random_state = 0)
rf_regressor.fit(X_train,y_train)

#Predecir el precio de venta  
y_pred = rf_regressor.predict(X_test)

#Calcular métricas
mae_rf=metrics.mean_absolute_error(y_test, y_pred)
mse_rf=metrics.mean_squared_error(y_test, y_pred)
r2_rf=metrics.r2_score(y_test, y_pred)

#Imprimir métricas
print('R2 square:',r2_rf)
print('MAE: ', mae_rf)
print('MSE: ', mse_rf)
# Out:
# R2 square: 0.3060990729742965
# MAE:  3.030675105485233
# MSE:  14.228471308016879

# %% [markdown]
# #### Máquina de vector soporte

# %%
from sklearn.svm import SVR

# %%
#Inicializar objeto
regressor= SVR(kernel='rbf')
#Entrenar modelo
regressor.fit(X_train,y_train)
#Predecir
y_pred_svm=regressor.predict(X_test)

#Calcular métricas
mae_svr=metrics.mean_absolute_error(y_test, y_pred_svm)
mse_svr=metrics.mean_squared_error(y_test, y_pred_svm)
r2_svr=metrics.r2_score(y_test, y_pred_svm)

# Imprimir Métricas
print('R2 square:',r2_svr)
print('MAE: ', mae_svr)
print('MSE: ', mse_svr)
# Out:
# R2 square: 0.12160470659059441
# MAE:  3.403685260277021
# MSE:  18.01153701140658

# %% [markdown]
# Hasta ahora el mejor modelo es el random forest porque tiene un $R^2$ más grande y sus errores son menores.

# %% [markdown]
# #### Optimicemos los parámetros de ambos modelos

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold

# %%
#Configurar los folds que vamos a usar para todos los modelos
n_folds = 5
seed = 7
scoring = 'neg_mean_squared_error'
kfold = KFold(n_splits=n_folds, random_state=seed, shuffle=True)

# %% [markdown]
# #### Random Forest

# %%
from sklearn.model_selection import train_test_split,cross_val_score, cross_val_predict

# %%
#Usando cross validation y grid search
#Inicializo modelo
model = RandomForestRegressor(min_samples_leaf=1,
                               max_features='auto',
                               bootstrap=True,
                               oob_score=False,
                               random_state=0,
                               verbose=0)
#Grid search para optimizar hiperparámetros
gs = GridSearchCV(model,
                  param_grid = {'max_depth': range(1, 11),
                                'min_samples_split': range(10, 60, 10),
                                'n_estimators': [100, 300, 500, 800],
                                'criterion': ['mse']}, 
                  cv=kfold,
                  scoring='neg_mean_squared_error')
gs.fit(X_train, y_train)

print(gs.best_params_)
# Out:
# {'criterion': 'mse', 'max_depth': 8, 'min_samples_split': 20, 'n_estimators': 100}

# %% [markdown]
# Volvemos a hacer el modelo de random forest pero con los parámetros óptimos que obtuvimos con el GridSearch

# %%
#crear modelo usando parámetros óptimos
new_model_RF = RandomForestRegressor(n_estimators=100,
                               criterion='mse',
                               max_depth=8,
                               min_samples_split=20,
                               min_samples_leaf=1,
                               max_features='auto',
                               bootstrap=True,
                               oob_score=False,
                               random_state=0,
                               verbose=0)
#Entreno modelo optimizado
new_model_RF.fit(X_train, y_train)

r2_lr= (cross_val_score(lm, X_train,y_train, cv=kfold,  scoring='r2')).mean()
print("R2", r2_lr)
mae_lr= -(cross_val_score(lm, X_train,y_train, cv=kfold,  scoring='neg_mean_absolute_error')).mean()
print("MAE", mae_lr)
mse_rf= (-cross_val_score(new_model_RF, X_train,y_train, cv=kfold,  scoring='neg_mean_squared_error')).mean()
print("MSE", mse_rf)
# Out:
# R2 -0.006092172900484583
# MAE 3.4457321212240712
# MSE 15.496259989115961

# %% [markdown]
# El MSE no mejoró. Pasó de ser 14.22 a ser 15.61. El  $R^2$ y el MAE también empeoraron.

# %% [markdown]
# #### Máquina de vector soporte

# %%
#proponer malla para el gridsearch
tuned_parameters = [{'kernel': ['rbf'], 'gamma': [1e-3, 1e-4],'C': [1, 10, 100, 1000]},
                    {'kernel': ['linear'], 'C': [1, 10, 100, 1000]}]

model = SVR()

gs = GridSearchCV(model,
                  tuned_parameters, 
                  cv=kfold,
                  scoring='neg_mean_squared_error')

gs.fit(X_train, y_train)

print(gs.best_params_)
# Out:
# {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}

# %% [markdown]
# Volvemos a hacer el modelo de SVR con los parámetros óptimos que obtuvimos con el GridSearch.

# %%
#crear modelo usando parámetros óptimos
new_model_svr = SVR(kernel='rbf', C=10, gamma=0.001)
mse_svr= (-cross_val_score(new_model_svr, X_train,y_train, cv=kfold,  scoring='neg_mean_squared_error')).mean()
print("MSE", mse_svr)
mae_svr= -(cross_val_score(new_model_svr, X_train,y_train, cv=kfold,  scoring='neg_mean_absolute_error')).mean()
print("MAE", mae_svr)
r2_svr= (cross_val_score(new_model_svr, X_train,y_train, cv=kfold,  scoring='r2')).mean()
print("R2", r2_svr)
# Out:
# MSE 19.116185707872866
# MAE 3.2046414014548033
# R2 0.06497075114181006

# %% [markdown]
# El MSE no mejoró, subió de $18.01$ a $19.1$. El MAE y el R2 también empeoraron.

# %% [markdown]
# #### ¿Y si lo hacemos solo con las variables seleccionadas?

# %%
X_train
# Out:
#           age      Medu      Fedu  traveltime  studytime  failures    famrel  \
# 0   -0.586396  0.246437  0.423207   -0.625779  -0.056853 -0.456744  0.064432
# 1   -0.586396 -0.680636  0.423207    0.828236  -1.254553 -0.456744  1.195575
# 2   -0.586396 -1.607709  0.423207   -0.625779  -0.056853  3.628097  0.064432
# 3   -0.586396  1.173510  0.423207   -0.625779   1.140847 -0.456744 -1.066710
# 4   -0.586396 -0.680636 -1.434203    0.828236  -1.254553 -0.456744 -1.066710
# ..        ...       ...       ...         ...        ...       ...       ...
# 311 -1.374912  1.173510 -0.505498   -0.625779   2.338548 -0.456744 -1.066710
# 312 -1.374912 -0.680636 -0.505498   -0.625779   2.338548 -0.456744  1.195575
# 313  1.779151  0.246437  0.423207   -0.625779  -0.056853  2.266484  0.064432
# 314  0.202119  1.173510  0.423207   -0.625779   1.140847 -0.456744  0.064432
# 315 -1.374912  1.173510  1.351912   -0.625779  -1.254553 -0.456744  1.195575
#
# ...

# %%
X_train_fs = X_train.copy()
X_train_fs = X_train_fs.drop(columns = ['Fjob_health', 'schoolsup_no', 'higher_no', 'higher_yes'])
X_train_fs
# Out:
#           age      Medu      Fedu  traveltime  studytime  failures    famrel  \
# 0   -0.586396  0.246437  0.423207   -0.625779  -0.056853 -0.456744  0.064432
# 1   -0.586396 -0.680636  0.423207    0.828236  -1.254553 -0.456744  1.195575
# 2   -0.586396 -1.607709  0.423207   -0.625779  -0.056853  3.628097  0.064432
# 3   -0.586396  1.173510  0.423207   -0.625779   1.140847 -0.456744 -1.066710
# 4   -0.586396 -0.680636 -1.434203    0.828236  -1.254553 -0.456744 -1.066710
# ..        ...       ...       ...         ...        ...       ...       ...
# 311 -1.374912  1.173510 -0.505498   -0.625779   2.338548 -0.456744 -1.066710
# 312 -1.374912 -0.680636 -0.505498   -0.625779   2.338548 -0.456744  1.195575
# 313  1.779151  0.246437  0.423207   -0.625779  -0.056853  2.266484  0.064432
# 314  0.202119  1.173510  0.423207   -0.625779   1.140847 -0.456744  0.064432
# 315 -1.374912  1.173510  1.351912   -0.625779  -1.254553 -0.456744  1.195575
#
# ...

# %% [markdown]
# Ahora en lugar de tener 56 columnas, tenemos 52.

# %% [markdown]
# #### Random Forest

# %%
#Usando cross validation y grid search
#Inicializo modelo
model = RandomForestRegressor(min_samples_leaf=1,
                               max_features='auto',
                               bootstrap=True,
                               oob_score=False,
                               random_state=0,
                               verbose=0)
#Grid search para optimizar hiperparámetros
gs = GridSearchCV(model,
                  param_grid = {'max_depth': range(1, 11),
                                'min_samples_split': range(10, 60, 10),
                                'n_estimators': [100, 300, 500, 800],
                                'criterion': ['mse']}, 
                  cv=kfold,
                  scoring='neg_mean_squared_error')
gs.fit(X_train_fs, y_train)

print(gs.best_params_)
# Out:
# {'criterion': 'mse', 'max_depth': 10, 'min_samples_split': 20, 'n_estimators': 300}

# %%
from sklearn.linear_model import LinearRegression

# %%
#crear modelo usando parámetros óptimos
new_model_RF = RandomForestRegressor(n_estimators=300,
                               criterion='mse',
                               max_depth=10,
                               min_samples_split=20,
                               min_samples_leaf=1,
                               max_features='auto',
                               bootstrap=True,
                               oob_score=False,
                               random_state=0,
                               verbose=0)
#Entreno modelo optimizado
new_model_RF.fit(X_train_fs, y_train)

r2_lr= (cross_val_score(lm, X_train_fs,y_train, cv=kfold,  scoring='r2')).mean()
print("R2", r2_lr)
mae_lr= -(cross_val_score(lm, X_train_fs,y_train, cv=kfold,  scoring='neg_mean_absolute_error')).mean()
print("MAE", mae_lr)
mse_rf= (-cross_val_score(new_model_RF, X_train_fs,y_train, cv=kfold,  scoring='neg_mean_squared_error')).mean()
print("MSE", mse_rf)
# Out:
# R2 -0.014963667085829923
# MAE 3.497202354329265
# MSE 15.687677392944

# %% [markdown]
# + El MSE empeoró, pasó de ser 15.49 a ser 15.68.
# + El MAE también empeoró un poco, pasó de ser 3.44 a ser 3.49.
# + El $R^2$ también empeoró. Pasó de ser -0.00609 a ser -0.0149.
#
# No nos beneficia eliminar las 5 variables.

# %% [markdown]
# #### SVC

# %%
#proponer malla para el gridsearch
tuned_parameters = [{'kernel': ['rbf'], 'gamma': [1e-3, 1e-4],'C': [1, 10, 100, 1000]},
                    {'kernel': ['linear'], 'C': [1, 10, 100, 1000]}]

model = SVR()

gs = GridSearchCV(model,
                  tuned_parameters, 
                  cv=kfold,
                  scoring='neg_mean_squared_error')

gs.fit(X_train_fs, y_train)

print(gs.best_params_)
# Out:
# {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}

# %% [markdown]
# Eligió los mismos parámetros que el modelo anterior.

# %%
#crear modelo usando parámetros óptimos
new_model_svr_fs = SVR(kernel='rbf', C=10, gamma=0.001)
mse_svr_fs= (-cross_val_score(new_model_svr_fs, X_train_fs, y_train, cv=kfold,  scoring='neg_mean_squared_error')).mean()
print("MSE", mse_svr_fs)
mae_svr_fs = -(cross_val_score(new_model_svr_fs, X_train_fs, y_train, cv=kfold,  scoring='neg_mean_absolute_error')).mean()
print("MAE", mae_svr_fs)
r2_svr_fs = (cross_val_score(new_model_svr_fs, X_train_fs, y_train, cv=kfold,  scoring='r2')).mean()
print("R2", r2_svr_fs)
# Out:
# MSE 19.226436740490346
# MAE 3.206357587768442
# R2 0.06084059369462065

# %% [markdown]
# Obtenemos el mismo MSE que el modelo anterior.

# %% [markdown]
# ### Conclusiones
# + Resultados:
#     + El primer modelo de random forest fue el mejor ya que sus 3 métricas fueron mejores.
#     + El primer modelo de SVR fue el mejor ya que su R2 y su  MSE fueron mejores.
#     + El mejor modelo para nuestros datos fue el random forest, el primer modelo que hicimos. Tiene un R2 de 0.306099, un de MAE 3.03067 y un MSE de 14.2284713.
#
# + Los random forest tienen que optimizar 4 hiperparámetros.
# + Las máquinas de vector soporte tienen que optimizar 3 hiperparámetros.
# + La optimización de parámetros de ambos modelos tardó mucho, alrededor de 10 o 15 minutos, no hay uno que convenga más si se quiere ahorrar tiempo, no hay mucha diferencia entre ambos. Probablemente el random forest tome más tiempo porque optimiza 4 hiperparámetros.
# + Lo bueno del modelo SVC es que obtuvimos el mismo resultado de MSE aún sin las 5 variables que eliminamos, esto hace que sea más rápido de calcular para la computadora.
# + Para el modelo Random Forest no fue buena idea eliminar las variables que seleccionó el modelo basado en árboles, ya que las 3 métricas empeoraron.
